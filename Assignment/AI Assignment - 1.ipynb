# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/House Price India.csv')

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %% [markdown]
# ##Univariate Analysis

# %%
##Univariate Analysis
df_price = df.loc[df['Price']>=3000000]
df_year = df.loc[df['Built Year']>1990]
df_ryear = df.loc[df['Renovation Year']>2000]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df_price
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 243    6762810052  42496                   7                 4.50
# 1622   6762810059  42518                   6                 4.25
# 1697   6762810035  42519                   4                 3.50
# 2424   6762810021  42531                   5                 4.50
# 2794   6762810027  42537                   5                 6.75
# 2907   6762810029  42538                   4                 3.00
# 2908   6762810065  42538                   4                 4.25
# 3234   6762810043  42543                   3                 4.50
# 3376   6762810062  42544                   4                 5.00
# 3946   6762810033  42551                   5                 5.50
# 4061   6762810047  42552                   5                 6.25
# 5887   6762810060  42579                   5                 5.25
# 6244   6762810023  42585                   5                 5.75
# ...

# %%
plt.plot(df_price['number of bedrooms'])

# %%
plt.plot(df_price['number of bedrooms'],np.zeros_like(df_price['number of bedrooms']),'o')
plt.xlabel('Number of Bathrooms')
# Out:
# Text(0.5, 0, 'Number of Bathrooms')

# %%
plt.plot(df_ryear['Renovation Year'],np.zeros_like(df_ryear['Renovation Year']),'o')
plt.plot(df_year['Built Year'],np.zeros_like(df_year['Built Year']),'v')
#plt.show()

# %%
#Another Example for the Univariate

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df_grade1 = df.loc[df['grade of the house']== 10]
df_grade2 = df.loc[df['grade of the house'] == 9]
df_grade3 = df.loc[df['grade of the house'] == 8]

# %%
plt.plot(df_grade1['Price'],np.zeros_like(df_grade1['Price']),'o')
plt.plot(df_grade2['Price'],np.zeros_like(df_grade2['Price']),'o')
plt.plot(df_grade3['Price'],np.zeros_like(df_grade3['Price']),'o')
plt.show()

# %% [markdown]
# ##Bivariate Analysis

# %%
plt.figure(figsize=(50,50))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.FacetGrid(df,hue="Price",size=5).map(plt.scatter,"Built Year", "Renovation Year").add_legend();
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-af76acee4757> in <cell line: 1>()
# ----> 1 sns.FacetGrid(df,hue="Price",size=5).map(plt.scatter,"Built Year", "Renovation Year").add_legend();
#       2 plt.show()
#
# TypeError: __init__() got an unexpected keyword argument 'size'

# %%
plt.figure(figsize=(20,10))
sns.
sns.barplot(data=df,x='grade of the house',y='Price')
# Out:
# <Axes: xlabel='grade of the house', ylabel='Price'>

# %%
new_grade = df.loc[df['grade of the house']>=10]
sns.pairplot(new_grade, hue="grade of the house",size = 6)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # **4.descriptive statistics**

# %%
#dd = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df['number of bedrooms'].value_counts()
# Out:
# 3     6612
# 4     4724
# 2     1844
# 5     1079
# 6      176
# 1      136
# 7       30
# 8       11
# 9        3
# 10       3
# 33       1
# 11       1
# Name: number of bedrooms, dtype: int64

# %%
df['number of bedrooms'].value_counts().to_frame()
# Out:
#     number of bedrooms
# 3                 6612
# 4                 4724
# 2                 1844
# 5                 1079
# 6                  176
# 1                  136
# 7                   30
# 8                   11
# 9                    3
# 10                   3
# 33                   1
# 11                   1

# %%
new_count = df['number of bedrooms'].value_counts().to_frame()
new_count.rename(columns={'number of bedrooms':'new count'}, inplace = True)
new_count
# Out:
#     new count
# 3        6612
# 4        4724
# 2        1844
# 5        1079
# 6         176
# 1         136
# 7          30
# 8          11
# 9           3
# 10          3
# 33          1
# 11          1

# %%
new_count.index.name = "s.no"
new_count
# Out:
#       new count
# s.no
# 3          6612
# 4          4724
# 2          1844
# 5          1079
# 6           176
# 1           136
# 7            30
# 8            11
# 9             3
# 10            3
# 33            1
# 11            1

# %% [markdown]
# # **5. Handle Missing values(NULL Values)**

# %%
df.isnull()
# Out:
#           id   Date  number of bedrooms  number of bathrooms  living area  \
# 0      False  False               False                False        False
# 1      False  False               False                False        False
# 2      False  False               False                False        False
# 3      False  False               False                False        False
# 4      False  False               False                False        False
# ...      ...    ...                 ...                  ...          ...
# 14615  False  False               False                False        False
# 14616  False  False               False                False        False
# 14617  False  False               False                False        False
# 14618  False  False               False                False        False
# 14619  False  False               False                False        False
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
dd = pd.read_csv('/Data1 (1).csv')
dd
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
dd.isnull()
# Out:
#    Country    Age  Salary  Purchased
# 0    False  False   False      False
# 1    False  False   False      False
# 2    False  False   False      False
# 3    False  False   False      False
# 4    False  False    True      False
# 5    False  False   False      False
# 6    False   True   False      False
# 7    False  False   False      False
# 8    False  False   False      False
# 9    False  False   False      False

# %%
dd.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
#dd.isnull().sum().sum()
## Filling the Null Values

dd1 = dd.fillna(value=0)#can any values 
dd1
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      0.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   0.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#fill the Null values with the previous value
dd3=dd.fillna(method='pad')
dd3
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  61000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  35.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#fill the Null values with the next value
dd4=dd.fillna(method='bfill')
dd4
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  58000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  48.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#fill the Null values with the column before value
dd5=dd.fillna(method='pad', axis = 1)
dd5
# Out:
#    Country    Age   Salary Purchased
# 0   France   44.0  72000.0        No
# 1    Spain   27.0  48000.0       Yes
# 2  Germany   30.0  54000.0        No
# 3    Spain   38.0  61000.0        No
# 4  Germany   40.0     40.0       Yes
# 5   France   35.0  58000.0       Yes
# 6    Spain  Spain  52000.0        No
# 7   France   48.0  79000.0       Yes
# 8  Germany   50.0  83000.0        No
# 9   France   37.0  67000.0       Yes

# %%
#fill the Null values with the next column  value
dd6=dd.fillna(method='bfill', axis=1)
dd6
# Out:
#    Country      Age   Salary Purchased
# 0   France     44.0  72000.0        No
# 1    Spain     27.0  48000.0       Yes
# 2  Germany     30.0  54000.0        No
# 3    Spain     38.0  61000.0        No
# 4  Germany     40.0      Yes       Yes
# 5   France     35.0  58000.0       Yes
# 6    Spain  52000.0  52000.0        No
# 7   France     48.0  79000.0       Yes
# 8  Germany     50.0  83000.0        No
# 9   France     37.0  67000.0       Yes

# %%
# insert the new element in the Null from the column head
dd7 = dd.fillna({'Age':'Wrong Age',
                'Salary':'No Salary'})
dd7
# Out:
#    Country        Age     Salary Purchased
# 0   France       44.0    72000.0        No
# 1    Spain       27.0    48000.0       Yes
# 2  Germany       30.0    54000.0        No
# 3    Spain       38.0    61000.0        No
# 4  Germany       40.0  No Salary       Yes
# 5   France       35.0    58000.0       Yes
# 6    Spain  Wrong Age    52000.0        No
# 7   France       48.0    79000.0       Yes
# 8  Germany       50.0    83000.0        No
# 9   France       37.0    67000.0       Yes

# %%
#Eliminate the Nan from the Table
dd8 = dd.dropna()
dd8
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
dd8 = dd.dropna(how='any')
dd8
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
##Replacing the Nan value with other values

dd9 = dd.replace(to_replace=np.nan, value=9839714)
dd9
# Out:
#    Country        Age     Salary Purchased
# 0   France       44.0    72000.0        No
# 1    Spain       27.0    48000.0       Yes
# 2  Germany       30.0    54000.0        No
# 3    Spain       38.0    61000.0        No
# 4  Germany       40.0  9839714.0       Yes
# 5   France       35.0    58000.0       Yes
# 6    Spain  9839714.0    52000.0        No
# 7   France       48.0    79000.0       Yes
# 8  Germany       50.0    83000.0        No
# 9   France       37.0    67000.0       Yes

# %%
dd9 = dd.replace(to_replace='France', value="india")
dd9
# Out:
#    Country   Age   Salary Purchased
# 0    india  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5    india  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7    india  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9    india  37.0  67000.0       Yes
